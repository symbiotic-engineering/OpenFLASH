# %%
import os
import shutil
import subprocess

print(shutil.which("latex"))
print(os.environ["PATH"])

# subprocess.run(["latex", "--version"], check=True)
# Out:
# /usr/bin/latex
# /opt/conda/envs/openflash.openflash-on-branch-tex/bin:/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin

# %%
import sys
from pathlib import Path
HERE = Path.cwd().resolve()
utils_path = str((HERE / "sea-lab-utils").resolve())
# Define the path to the directory containing the package
if utils_path not in sys.path:
    sys.path.insert(0, utils_path)

# %%
# Now you can import from the folder structure
# Assuming 'pyplotutilities' is a folder inside 'sea-lab-utils'
from pyplotutilities import colors
from pyplotutilities import fonts
colors.get_colors()
print(colors.purple)
fonts.get_fonts()
# Out:
# #CC79A7

# %%
# import matplotlib.pyplot as plt
# fig, ax = plt.subplots()
# ax.plot([1, 2, 3], [1, 4, 9], color=colors.purple, label='Quadratic')
# ax.set_title('Sample Plot')
# ax.set_xlabel('$\mathbf{X}$-axis')
# ax.set_ylabel('$\phi$')
#fig.savefig('sample_plot.pdf', format='pdf', dpi=300, bbox_inches='tight')
